# %%
import pickle
import pandas as pd

# %%
with open('all_movie_data.pkl', 'rb') as ipt:
    df = pickle.load(ipt)

# %%
df
# Out:
# defaultdict(dict,
#             {'/movies/?id=pattyhearst.htm': {'budget': 'N/A',
#               'distributor': 'Atlantic',
#               'domestic': '$1,223,326',
#               'genre': 'Unknown',
#               'rating': 'R',
#               'release': 'September 23, 1988',
#               'runtime': '1 hrs. 48 min.'},
#              '/movies/?id=robinhoodprinceofthieves.htm': {'budget': '$48 million',
#               'distributor': 'Warner Bros.',
#               'domestic': '$165,493,908',
#               'foreign': '\xa0$225,000,000',
#               'genre': 'Period Adventure',
#               'rating': 'PG-13',
#               'release': 'June 14, 1991',
#               'runtime': '2 hrs. 23 min.'},
#              '/movies/?id=blackcatwhitecat.htm': {'budget': 'N/A',
#               'distributor': 'USA Films',
#               'domestic': '$351,447',
#               'genre': 'Unknown',
#               'rating': 'R',
#               'release': 'September 10, 1999',
# ...
