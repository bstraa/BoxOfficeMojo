# %%
import pickle
import pandas as pd

# %%
with open('all_movie_data2.pkl', 'rb') as pk:
    url_list = pickle.load(pk)

# %%
url_list
# Out:
# defaultdict(dict,
#             {'/movies/?id=missyoualready.htm': {'budget': 'N/A',
#               'distributor': 'Roadside Attractions',
#               'domestic': '$1,162,653',
#               'foreign': '\xa0n/a',
#               'genre': 'Drama',
#               'rating': 'PG-13',
#               'release': 'November 6, 2015',
#               'runtime': '1 hrs. 52 min.'},
#              '/movies/?id=judgmentnight.htm': {'budget': 'N/A',
#               'distributor': 'Universal',
#               'domestic': '$12,526,677',
#               'genre': 'Action Thriller',
#               'rating': 'R',
#               'release': 'October 15, 1993',
#               'runtime': '1 hrs. 50 min.'},
#              '/movies/?id=blackknight.htm': {'budget': '$50 million',
#               'distributor': 'Fox',
#               'domestic': '$33,426,971',
#               'foreign': '\xa0$6,549,264',
#               'genre': 'Adventure Comedy',
#               'rating': 'PG-13',
# ...

# %%
pd.DataFrame(url_list).T
# Out:
#                                                     budget  \
# /movies/?id=1000ae.htm                        $130 million
# /movies/?id=1001rabbittales.htm                        N/A
# /movies/?id=100foot.htm                        $22 million
# /movies/?id=1952.htm                          $190 million
# /movies/?id=1dwhereweare.htm                           NaN
# /movies/?id=32filmsaboutglenngould.htm                 N/A
# /movies/?id=3burialsofmelquiadesestrada.htm    $15 million
# /movies/?id=3d06.htm                                   N/A
# /movies/?id=40shadesofblue.htm                $1.5 million
# /movies/?id=4daysinseptember.htm                       N/A
# /movies/?id=5050.htm                                   N/A
# /movies/?id=6weeks.htm                                 N/A
# /movies/?id=HARVARDBEATSYALE2929.HTM                   N/A
# /movies/?id=aaa.htm                                    N/A
# /movies/?id=aajanachle.htm                             N/A
# ...
